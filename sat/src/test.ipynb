# %%
from sat import *

# %%
import os

os.chdir('/Users/soulofshadow/Desktop/VLSI/')
os.getcwd()
# Out:
# '/Users/soulofshadow/Desktop/VLSI'

# %%
instance = 2

result = run(instance)
if result is not None:
    print(result)
    plot_result(result)
    write_file(result)
# Out:
# It's best height is 9
# {'i': 2, 'w': 9, 'n': 5, 'width': [3, 3, 3, 3, 3], 'height': [3, 4, 5, 6, 9], 'x': [0, 6, 6, 0, 3], 'y': [0, 0, 4, 3, 0], 'h': 9, 'duration': '0:00:00.005771'}
